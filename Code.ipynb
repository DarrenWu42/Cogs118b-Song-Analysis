# %% [markdown]
# # COGS 118B Final Project

# %% [markdown]
# ## Pre-Reqs

# %%
# required imports

import random
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from itertools import islice
import matplotlib.pyplot as plt
from collections import defaultdict
from scipy.spatial.distance import cdist
from sklearn.mixture import GaussianMixture

# do not show warning for division by 0
_ = np.seterr(divide='ignore', invalid='ignore')

# do not show pairplots warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Exploring the Data

# %%
# import dataset and display it

data = pd.read_csv('Data.csv', encoding='cp1252').drop('Index', axis=1)
original_size = len(data)

data
# Out:
#                        Title                    Artist            Top Genre  \
# 0                    Sunrise               Norah Jones      adult standards
# 1                Black Night               Deep Purple           album rock
# 2             Clint Eastwood                  Gorillaz  alternative hip hop
# 3              The Pretender              Foo Fighters    alternative metal
# 4     Waitin' On A Sunny Day         Bruce Springsteen         classic rock
# ...                      ...                       ...                  ...
# 1989        Heartbreak Hotel             Elvis Presley      adult standards
# 1990               Hound Dog             Elvis Presley      adult standards
# 1991         Johnny B. Goode               Chuck Berry           blues rock
# 1992               Take Five  The Dave Brubeck Quartet                bebop
# 1993          Blueberry Hill               Fats Domino      adult standards
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0     2004                     157      30            53            -14
# 1     2000                     135      79            50            -11
# 2     2001                     168      69            66             -9
# 3     2007                     173      96            43             -4
# 4     2002                     106      82            58             -5
# ...    ...                     ...     ...           ...            ...
# 1989  1958                      94      21            70            -12
# 1990  1958                     175      76            36             -8
# 1991  1959                     168      80            53             -9
# 1992  1959                     174      26            45            -13
# 1993  1959                     133      50            49            -10
#
#       Liveness  Valence Length (Duration)  Acousticness  Speechiness  \
# 0           11       68               201            94            3
# 1           17       81               207            17            7
# 2            7       52               341             2           17
# 3            3       37               269             0            4
# 4           10       87               256             1            3
# ...        ...      ...               ...           ...          ...
# 1989        11       72               128            84            7
# 1990        76       95               136            73            6
# 1991        31       97               162            74            7
# 1992         7       60               324            54            4
# 1993        16       83               148            74            3
#
#       Popularity
# 0             71
# 1             39
# 2             69
# 3             76
# 4             59
# ...          ...
# 1989          63
# 1990          69
# 1991          74
# 1992          65
# 1993          56
#
# [1994 rows x 14 columns]

# %%
# check for missing data

print(f'There are {data.isnull().sum().sum()} missing values.')
# Out:
# There are 0 missing values.

# %%
# extract audio features relevant to clustering

features = list(data.columns[4:13])
del features[6]

print('The following features from the dataset will be used for clustering:\n')

for i, feature in enumerate(features):
    print(f'{i + 1} - {feature}')
# Out:
# The following features from the dataset will be used for clustering:
#
# 1 - Beats Per Minute (BPM)
# 2 - Energy
# 3 - Danceability
# 4 - Loudness (dB)
# 5 - Liveness
# 6 - Valence
# 7 - Acousticness
# 8 - Speechiness

# %%
# extract the genres and display them

def get_genres():
    return sorted(data['Top Genre'].unique(), reverse = True, 
                  key = lambda genre: len(data.loc[data['Top Genre'] == genre]))

def display_genres():
    genres = get_genres()
    
    print(f'Displaying {len(genres)} genres.\n')
    
    longest_length = len(max(genres, key = len))
    
    print(f'{"idx":{3}} | {"genres":^{longest_length}} | {"# entries":^{3}}\n' + '-' * (longest_length + 18))
    
    for i, genre in enumerate(genres):
        num = len(data.loc[data['Top Genre'] == genre])
        print(f'{i + 1:<{3}} | {genre:{longest_length}} | {num:<{9}}')
    
display_genres()
# Out:
# Displaying 149 genres.
#
# idx |           genres            | # entries
# ---------------------------------------------
# 1   | album rock                  | 413
# 2   | adult standards             | 123
# 3   | dutch pop                   | 88
# 4   | alternative rock            | 86
# 5   | dance pop                   | 83
# 6   | dutch indie                 | 75
# 7   | alternative metal           | 70
# 8   | dance rock                  | 52
# 9   | classic rock                | 51
# 10  | dutch cabaret               | 51
# 11  | modern rock                 | 49
# 12  | glam rock                   | 49
# 13  | pop                         | 47
# 14  | art rock                    | 40
# 15  | permanent wave              | 38
# 16  | british invasion            | 36
# 17  | irish rock                  | 34
# 18  | british soul                | 31
# 19  | europop                     | 27
# 20  | classic uk pop              | 22
# 21  | disco                       | 18
# 22  | dutch rock                  | 18
# 23  | neo mellow                  | 17
# 24  | glam metal                  | 17
# 25  | alternative dance           | 15
# 26  | blues rock                  | 15
# 27  | art pop                     | 14
# 28  | dutch hip hop               | 13
# 29  | funk                        | 13
# 30  | dutch americana             | 12
# 31  | britpop                     | 11
# 32  | mellow gold                 | 11
# 33  | big beat                    | 11
# 34  | classic soul                | 11
# 35  | carnaval limburg            | 10
# 36  | german pop                  | 9
# 37  | arkansas country            | 9
# 38  | chanson                     | 9
# 39  | australian pop              | 8
# 40  | belgian rock                | 8
# 41  | blues                       | 8
# 42  | reggae                      | 8
# 43  | folk                        | 8
# 44  | alternative pop rock        | 7
# 45  | detroit hip hop             | 7
# 46  | modern folk rock            | 7
# 47  | big room                    | 7
# 48  | celtic rock                 | 7
# 49  | electro                     | 7
# 50  | canadian folk               | 7
# 51  | chamber pop                 | 7
# 52  | boy band                    | 6
# 53  | east coast hip hop          | 6
# 54  | brill building pop          | 6
# 55  | baroque pop                 | 6
# 56  | celtic                      | 5
# 57  | canadian pop                | 5
# 58  | dutch prog                  | 5
# 59  | g funk                      | 5
# 60  | classic country pop         | 5
# 61  | garage rock                 | 4
# 62  | british folk                | 4
# 63  | downtempo                   | 4
# 64  | reggae fusion               | 4
# 65  | dutch metal                 | 4
# 66  | acoustic pop                | 4
# 67  | belgian pop                 | 4
# 68  | folk-pop                    | 4
# 69  | metropopolis                | 4
# 70  | eurodance                   | 3
# 71  | classic schlager            | 3
# 72  | barbadian pop               | 3
# 73  | australian rock             | 3
# 74  | electropop                  | 3
# 75  | edm                         | 3
# 76  | italian pop                 | 3
# 77  | bubblegum pop               | 3
# 78  | christelijk                 | 3
# 79  | alternative hip hop         | 2
# 80  | danish pop rock             | 2
# 81  | finnish metal               | 2
# 82  | bow pop                     | 2
# 83  | candy pop                   | 2
# 84  | scottish singer-songwriter  | 2
# 85  | contemporary country        | 2
# 86  | gabba                       | 2
# 87  | indie pop                   | 2
# 88  | nederpop                    | 2
# 89  | australian psych            | 2
# 90  | neo soul                    | 2
# 91  | austropop                   | 2
# 92  | latin                       | 2
# 93  | punk                        | 2
# 94  | new wave pop                | 2
# 95  | british alternative rock    | 2
# 96  | afropop                     | 1
# 97  | latin alternative           | 1
# 98  | hip pop                     | 1
# 99  | soft rock                   | 1
# 100 | acid jazz                   | 1
# 101 | operatic pop                | 1
# 102 | trance                      | 1
# 103 | alternative pop             | 1
# 104 | atl hip hop                 | 1
# 105 | uk pop                      | 1
# 106 | happy hardcore              | 1
# 107 | british singer-songwriter   | 1
# 108 | australian indie folk       | 1
# 109 | irish pop                   | 1
# 110 | electronica                 | 1
# 111 | alaska indie                | 1
# 112 | irish singer-songwriter     | 1
# 113 | stomp and holler            | 1
# 114 | australian dance            | 1
# 115 | laboratorio                 | 1
# 116 | contemporary vocal jazz     | 1
# 117 | rock-and-roll               | 1
# 118 | classic soundtrack          | 1
# 119 | icelandic indie             | 1
# 120 | danish pop                  | 1
# 121 | compositional ambient       | 1
# 122 | streektaal                  | 1
# 123 | indie anthem-folk           | 1
# 124 | la pop                      | 1
# 125 | ccm                         | 1
# 126 | electro house               | 1
# 127 | australian americana        | 1
# 128 | chicago soul                | 1
# 129 | hard rock                   | 1
# 130 | j-core                      | 1
# 131 | basshall                    | 1
# 132 | australian alternative rock | 1
# 133 | yacht rock                  | 1
# 134 | alternative country         | 1
# 135 | celtic punk                 | 1
# 136 | classic canadian rock       | 1
# 137 | levenslied                  | 1
# 138 | cyberpunk                   | 1
# 139 | gangster rap                | 1
# 140 | diva house                  | 1
# 141 | classical rock              | 1
# 142 | canadian rock               | 1
# 143 | german pop rock             | 1
# 144 | latin jazz                  | 1
# 145 | german alternative rock     | 1
# 146 | classic italian pop         | 1
# 147 | pop punk                    | 1
# 148 | motown                      | 1
# 149 | bebop                       | 1

# %% [markdown]
# ## Preparing the Data

# %%
# 149 genres leads to too many clusters. we reduce this number in two ways:
# 1: group similar genres together (ie: 'album rock' and 'alternative rock' are grouped under 'rock')
# 2: only pick the most represented genres in the dataset

# 1
def group_genres(groups):
    for group in groups:
        data.loc[[group in genre for genre in data['Top Genre']], 'Top Genre'] = group

group_genres(['rock', 'pop', 'indie', 'hip hop', 'soul', 'metal', 'country', 'folk', 'jazz', 'elec', 'dance'])

# 2 (only keep genres with more than 20 songs)
top_genres = [genre for genre in get_genres() if len(data.loc[data['Top Genre'] == genre]) > 20]
data = data[data['Top Genre'].isin(top_genres)]

display_genres()

print(f'\nThe dataset now has {len(data)} entries.\n{original_size - len(data)} entries were removed, ' +
       'keeping only songs that belong in a genre with 10 or more songs. ')

data
# Out:
# Displaying 10 genres.
#
# idx |      genres      | # entries
# ----------------------------------
# 1   | rock             | 857
# 2   | pop              | 388
# 3   | adult standards  | 123
# 4   | metal            | 93
# 5   | indie            | 79
# 6   | dutch cabaret    | 51
# 7   | soul             | 45
# 8   | permanent wave   | 38
# 9   | british invasion | 36
# 10  | hip hop          | 29
#
# The dataset now has 1739 entries.
# 255 entries were removed, keeping only songs that belong in a genre with 10 or more songs.
#                        Title             Artist        Top Genre  Year  \
# 0                    Sunrise        Norah Jones  adult standards  2004
# 1                Black Night        Deep Purple             rock  2000
# 2             Clint Eastwood           Gorillaz          hip hop  2001
# 3              The Pretender       Foo Fighters            metal  2007
# 4     Waitin' On A Sunny Day  Bruce Springsteen             rock  2002
# ...                      ...                ...              ...   ...
# 1988              Summertime    Louis Armstrong  adult standards  1958
# 1989        Heartbreak Hotel      Elvis Presley  adult standards  1958
# 1990               Hound Dog      Elvis Presley  adult standards  1958
# 1991         Johnny B. Goode        Chuck Berry             rock  1959
# 1993          Blueberry Hill        Fats Domino  adult standards  1959
#
#       Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 0                        157      30            53            -14        11
# 1                        135      79            50            -11        17
# 2                        168      69            66             -9         7
# 3                        173      96            43             -4         3
# 4                        106      82            58             -5        10
# ...                      ...     ...           ...            ...       ...
# 1988                     168       7            17            -21        14
# 1989                      94      21            70            -12        11
# 1990                     175      76            36             -8        76
# 1991                     168      80            53             -9        31
# 1993                     133      50            49            -10        16
#
#       Valence Length (Duration)  Acousticness  Speechiness  Popularity
# 0          68               201            94            3          71
# 1          81               207            17            7          39
# 2          52               341             2           17          69
# 3          37               269             0            4          76
# 4          87               256             1            3          59
# ...       ...               ...           ...          ...         ...
# 1988       10               298            92            3          66
# 1989       72               128            84            7          63
# 1990       95               136            73            6          69
# 1991       97               162            74            7          74
# 1993       83               148            74            3          56
#
# [1739 rows x 14 columns]

# %% [markdown]
# ## Displaying the Prepared Data

# %%
print('Below is a visualization of the range of the eight features we use for clustering:\n')

fig, axes = plt.subplots(4, 2, figsize=(15, 15))
fig = data.hist(column=features, ax=axes)
# Out:
# Below is a visualization of the range of the eight features we use for clustering:

# %%
print('Below are pairplots of our data using the eight features mentioned above:\n')

_ = plt.figure(figsize=(10, 10))
g = sns.pairplot(data[features + ['Top Genre']], hue = 'Top Genre')
_ = g.fig.suptitle('Pairplot of the Genre Distribution of the 8 Features')
# Out:
# Below are pairplots of our data using the eight features mentioned above:

# %%
print('Below are KDE pairplots of our data using the eight features mentioned above:\n')

_ = plt.figure(figsize=(10, 10))
g = sns.pairplot(data[features + ['Top Genre']], kind="kde")
_ = g.fig.suptitle('KDE Pairplot of the Genre Distribution of the 8 Features')
# Out:
# Below are KDE pairplots of our data using the eight features mentioned above:

# %% [markdown]
# ## Principal Component Analysis

# %%
# declare characteristics matrix

c_matrix = data[features].to_numpy().transpose()

# %%
# eigensort from hw4

# [Vsort,Dsort] = eigsort(V, eigvals)
#
# Sorts a matrix eigenvectors and a array of eigenvalues in order 
# of eigenvalue size, largest eigenvalue first and smallest eigenvalue
# last.
#
# Example usage:
# di, V = np.linarg.eig(L)
# Vnew, Dnew = eigsort(V, di)
#
# Tim Marks 2002
def eigsort(V, eigvals):
    
    # Sort the eigenvalues from largest to smallest. Store the sorted
    # eigenvalues in the column vector lambd.
    lohival = np.sort(eigvals)
    lohiindex = np.argsort(eigvals)
    lambd = np.flip(lohival)
    index = np.flip(lohiindex)
    Dsort = np.diag(lambd)
    
    # Sort eigenvectors to correspond to the ordered eigenvalues. Store sorted
    # eigenvectors as columns of the matrix vsort.
    M = np.size(lambd)
    Vsort = np.zeros((M, M))
    
    for i in range(M):
        Vsort[:,i] = V[:,index[i]]
        
    return Vsort, Dsort

# %%
# method to run pca

def pca(data_matrix, characteristics):
    c_matrix = data_matrix
    mean_c = np.mean(c_matrix, axis=1, keepdims=True)
    c_standardized=c_matrix-mean_c
    cov_matrix=np.matmul(c_standardized, c_standardized.transpose())/7
    dold, vold = np.linalg.eig(cov_matrix)
    v, d = eigsort(vold, dold)
    new_c_matrix = np.matmul(v[:,0:3].transpose(), c_standardized)
    
    return new_c_matrix, v, d

# %%
new_c_matrix, v, d = pca(c_matrix, features)
num_pc = 8
pc_list = ['PC'+str(i) for i in list(range(1, num_pc+1))]
v_df = pd.DataFrame.from_dict(dict(zip(pc_list, v)))
v_df['Feature'] = features
v_df = v_df.set_index('Feature')

print('Below is the heat map obtained from PCA.\n')

plt.figure(figsize=(10, 7))
_ = sns.heatmap(v_df, annot=True, cmap='Spectral')
plt.title('Heatmap');
plt.show()
# Out:
# Below is the heat map obtained from PCA.

# %%
index_values = np.arange(8)+1
normalized_variability = d.diagonal()/sum(d.diagonal())

plt.figure(figsize=(10, 7))
plt.bar(index_values,normalized_variability)
plt.title('Scree Plot');
plt.xlabel('Principal Component');
plt.ylabel('Percentage of Variance');
plt.xticks(index_values, pc_list);

print(f'Below is the scree plot obtained from PCA.\nThe top 3 components make up for ' + 
      f'{normalized_variability[0]+normalized_variability[1]+normalized_variability[2]:.2f}% of the variability.\n')
# Out:
# Below is the scree plot obtained from PCA.
# The top 3 components make up for 0.81% of the variability.

# %% [markdown]
# From the Scree plot we can see that the first 3 components have the largest effect on the variability of the data, so we should focus on using those for further analysis. They make up 81.1%, which is above the recommended 80% threshold.

# %%
plt.figure(figsize=(10, 7))
plt.scatter(new_c_matrix[0], new_c_matrix[1]);
plt.title('First Two Columns of Data in New Basis');
plt.xlabel('PC1');
plt.ylabel('PC2');

# %%
fig = plt.figure(figsize=(10,10));
axes = fig.add_subplot(projection='3d');
axes.scatter(new_c_matrix[0], new_c_matrix[1], new_c_matrix[2]);
plt.title('First Three Columns of Data in New Basis');
axes.set_xlabel('PC1');
axes.set_ylabel('PC2');
axes.set_zlabel('PC3');

# %%
# find which features contribute the most

top_3_pcs = list(v_df.columns[:3])

imp_coeffs = {f: 0 for f in features}

for i, pc_col in enumerate(top_3_pcs):
    for idx in v_df.index:
        imp_coeffs[idx] += abs(v_df[pc_col][idx] * normalized_variability[i])
        
top_3_feats = list(dict(sorted(imp_coeffs.items(), reverse = True, key = lambda item: item[1])).keys())[:3]

print(f'The 3 features that contribute the most to clustering are {top_3_feats[0]}, {top_3_feats[1]}, and {top_3_feats[2]}.')
# Out:
# The 3 features that contribute the most to clustering are Energy, Liveness, and Valence.

# %% [markdown]
# ## K-Means Clustering

# %%
# methods to run k-means and display the results (inspired by hw2)

def k_means(k, feats):
    final_rnk = None
    prev_centroids = None
    
    centroids_idxs = [random.randrange(0, len(feats), 1) for i in range(k)]
    centroids = np.array([f for i, f in enumerate(feats) if i in centroids_idxs])
    
    while True:
        dist_mat = cdist(feats, centroids)
        rnk = np.array([np.amin(dist_mat, axis = 1)] * len(dist_mat[0])).T == dist_mat

        prev_centroids = centroids
        centroids = (np.matmul(feats.T, rnk).T / 
                     np.array([np.sum(rnk, axis = 0)] * len(feats[0])).T)
                
        if abs(np.nansum(centroids - prev_centroids)) < 1e-6:
            final_rnk = rnk
            break
    
    c_d_l = []
    c_c = []
    c_d = {}
    
    for i, c in enumerate(final_rnk.T):
        c_d[i] = np.nonzero(c)
        c_c.append(len(c_d[i][0]))

    for k in c_d:
        c_d_l.append([data.iloc[i] for i in c_d[k]][0])
    
    return sorted(c_c, reverse=True), sorted(c_d_l, key=len, reverse=True)


def print_kmeans_cluster_counts(cluster_counts):
    print(f'{len(data[features].values.tolist())} data points were clustered as such:\n\n' + 
          f'{"cluster id"} | {"# in cluster"} \n' + '-' * (25))

    for i, c in enumerate(cluster_counts):
        print(f'{i + 1:^10} | {c:^14}')

# %% [markdown]
# ### Pre - PCA

# %%
cluster_counts, _ = k_means(np.array(len(top_genres)), np.array(data[features].values.tolist()))
print_kmeans_cluster_counts(cluster_counts)
# Out:
# 1739 data points were clustered as such:
#
# cluster id | # in cluster
# -------------------------
#     1      |      346
#     2      |      238
#     3      |      194
#     4      |      190
#     5      |      177
#     6      |      158
#     7      |      154
#     8      |      113
#     9      |       86
#     10     |       83

# %% [markdown]
# ### Post - PCA

# %%
cluster_counts, clustered_data = k_means(np.array(len(top_genres)), np.array(data[top_3_feats].values.tolist()))
print_kmeans_cluster_counts(cluster_counts)
# Out:
# 1739 data points were clustered as such:
#
# cluster id | # in cluster
# -------------------------
#     1      |      221
#     2      |      215
#     3      |      210
#     4      |      200
#     5      |      196
#     6      |      165
#     7      |      146
#     8      |      142
#     9      |      142
#     10     |      102

# %% [markdown]
# ### Genre Percentage in Each Cluster

# %%
clustered_genres = [[g for g in c['Top Genre']] for c in clustered_data]

def display_percentages(clustered_genres):
    # Find the genre count in each cluster
    genre_count = {}

    # Iterate through each cluster
    for i in range(len(clustered_genres)):
        temp = defaultdict(int)

        # Iterate through each genre in each cluster
        for genre in clustered_genres[i]:
            temp[genre] += 1

        genre_count["cluster "+str(i+1)] = temp

    genre_count_df = pd.DataFrame.from_dict(genre_count)
    genre_count_df = genre_count_df.fillna(0)
    genre_count_df = genre_count_df.astype(float)

    genre_percent_df = genre_count_df

    for i in range(len(genre_percent_df)):
        genre_percent_df["cluster "+ str(i+1)] = (round((genre_percent_df['cluster ' + str(i+1)] / 
                                                         genre_percent_df['cluster ' + str(i+1)].sum()) * 100))

    print('Below are the percentages of genres in each cluster:\n') 

    for c in genre_percent_df.columns:
        sorted_pers = genre_percent_df[c].sort_values(ascending=False)

        print(f'{c}:\n')

        for i, g in enumerate(list(sorted_pers.index.values)):
            print(f'{g} ({sorted_pers[g]:.0f}%)', end='')

            if i == len(list(sorted_pers.index.values)) - 1:
                print('\n' + '-' * 10 + '\n')
            else:
                print(',', end=' ')

display_percentages(clustered_genres)
# Out:
# Below are the percentages of genres in each cluster:
#
# cluster 1:
#
# rock (54%), pop (24%), adult standards (5%), indie (4%), hip hop (3%), soul (3%), metal (3%), british invasion (2%), dutch cabaret (1%), permanent wave (0%)
# ----------
#
# cluster 2:
#
# rock (43%), pop (22%), adult standards (9%), indie (8%), dutch cabaret (6%), soul (4%), permanent wave (4%), metal (3%), british invasion (1%), hip hop (0%)
# ----------
#
# cluster 3:
#
# rock (56%), pop (21%), metal (8%), indie (4%), hip hop (2%), dutch cabaret (2%), soul (2%), adult standards (1%), british invasion (1%), permanent wave (1%)
# ----------
#
# cluster 4:
#
# rock (53%), pop (18%), adult standards (13%), indie (5%), dutch cabaret (4%), hip hop (2%), soul (2%), british invasion (2%), metal (1%), permanent wave (0%)
# ----------
#
# cluster 5:
#
# rock (52%), pop (29%), indie (6%), adult standards (5%), dutch cabaret (3%), hip hop (2%), soul (2%), metal (1%), british invasion (1%), permanent wave (1%)
# ----------
#
# cluster 6:
#
# rock (51%), pop (21%), metal (19%), indie (3%), soul (2%), permanent wave (2%), dutch cabaret (1%), british invasion (1%), hip hop (0%), adult standards (0%)
# ----------
#
# cluster 7:
#
# rock (38%), pop (27%), adult standards (14%), dutch cabaret (5%), indie (4%), soul (3%), permanent wave (3%), metal (2%), hip hop (1%), british invasion (1%)
# ----------
#
# cluster 8:
#
# rock (42%), adult standards (19%), pop (18%), british invasion (9%), indie (4%), soul (3%), metal (2%), hip hop (1%), dutch cabaret (1%), permanent wave (1%)
# ----------
#
# cluster 9:
#
# rock (46%), pop (25%), metal (14%), permanent wave (9%), soul (3%), hip hop (1%), adult standards (1%), dutch cabaret (1%), indie (1%), british invasion (0%)
# ----------
#
# cluster 10:
#
# rock (54%), pop (18%), adult standards (7%), hip hop (5%), dutch cabaret (5%), british invasion (5%), indie (4%), metal (3%), soul (0%), permanent wave (0%)
# ----------

# %% [markdown]
# ## Gaussian Mixture Model Clustering

# %%
gmm = GaussianMixture(n_components = 10)

def print_gmm_cluster_counts(clusters):
    cluster_counts = sorted([list(clusters).count(c) for c in list(set(clusters))], reverse=True)
    
    print(f'{len(data[features].values.tolist())} data points were clustered as such:\n\n' + 
          f'{"cluster id"} | {"# in cluster"} \n' + '-' * (25))

    for i, c in enumerate(cluster_counts):
        print(f'{i + 1:^10} | {c:^14}')

# %% [markdown]
# ### Pre - PCA

# %%
gmm.fit(np.array(data[features].values.tolist()))
gmm_clusters = gmm.predict(np.array(data[features].values.tolist()))
print_gmm_cluster_counts(gmm_clusters)
# Out:
# 1739 data points were clustered as such:
#
# cluster id | # in cluster
# -------------------------
#     1      |      761
#     2      |      410
#     3      |      141
#     4      |      125
#     5      |       96
#     6      |       92
#     7      |       39
#     8      |       30
#     9      |       23
#     10     |       22

# %% [markdown]
# ### Post - PCA

# %%
gmm.fit(np.array(data[top_3_feats].values.tolist()))
print_gmm_cluster_counts(gmm.predict(np.array(data[top_3_feats].values.tolist())))
# Out:
# 1739 data points were clustered as such:
#
# cluster id | # in cluster
# -------------------------
#     1      |      335
#     2      |      294
#     3      |      291
#     4      |      183
#     5      |      146
#     6      |      141
#     7      |      114
#     8      |      107
#     9      |       67
#     10     |       61

# %% [markdown]
# ### Genre Percentage in Each Cluster

# %%
clustered_genres = [[] for i in range(10)]

for i, c in enumerate(gmm_clusters):
    clustered_genres[c].append(data.iloc[i]['Top Genre'])

display_percentages(clustered_genres)
# Out:
# Below are the percentages of genres in each cluster:
#
# cluster 1:
#
# pop (50%), rock (18%), indie (14%), adult standards (9%), dutch cabaret (5%), british invasion (5%), metal (0%), soul (0%), permanent wave (0%), hip hop (0%)
# ----------
#
# cluster 2:
#
# rock (49%), pop (25%), adult standards (6%), metal (6%), indie (5%), dutch cabaret (3%), permanent wave (3%), british invasion (2%), soul (1%), hip hop (1%)
# ----------
#
# cluster 3:
#
# rock (57%), metal (17%), pop (13%), indie (5%), dutch cabaret (3%), permanent wave (2%), adult standards (1%), soul (1%), british invasion (0%), hip hop (0%)
# ----------
#
# cluster 4:
#
# rock (49%), pop (20%), adult standards (9%), indie (5%), metal (5%), soul (4%), dutch cabaret (3%), british invasion (2%), permanent wave (2%), hip hop (0%)
# ----------
#
# cluster 5:
#
# rock (70%), pop (17%), permanent wave (9%), metal (4%), dutch cabaret (0%), adult standards (0%), indie (0%), british invasion (0%), soul (0%), hip hop (0%)
# ----------
#
# cluster 6:
#
# rock (54%), pop (20%), adult standards (9%), indie (6%), soul (4%), dutch cabaret (2%), metal (2%), hip hop (2%), british invasion (1%), permanent wave (1%)
# ----------
#
# cluster 7:
#
# rock (49%), pop (23%), adult standards (9%), dutch cabaret (6%), hip hop (5%), british invasion (4%), indie (2%), soul (2%), metal (1%), permanent wave (0%)
# ----------
#
# cluster 8:
#
# rock (41%), hip hop (21%), pop (18%), metal (8%), dutch cabaret (5%), soul (5%), indie (3%), adult standards (0%), british invasion (0%), permanent wave (0%)
# ----------
#
# cluster 9:
#
# rock (40%), pop (30%), adult standards (7%), soul (7%), hip hop (7%), dutch cabaret (3%), british invasion (3%), metal (3%), indie (0%), permanent wave (0%)
# ----------
#
# cluster 10:
#
# rock (46%), pop (31%), metal (10%), hip hop (7%), indie (2%), british invasion (2%), soul (1%), dutch cabaret (0%), adult standards (0%), permanent wave (0%)
# ----------

# %% [markdown]
# ## Finding Artists' Genres

# %%
# making a new dataframe with Artist and Top Genres
ag_df = data[['Artist', 'Top Genre']]

# making a dictionary with all artists as a key and an empty array as the value
ag_dict = {k: [] for k in ag_df['Artist'].unique()}

# iterating through each row and adding genres as a value for the respective artist
for row in ag_df.iterrows():
    ag_dict[row[1]['Artist']].append(row[1]['Top Genre'])

# removing all duplicate values 
for k in ag_dict:
    ag_dict[k] = list(set(ag_dict[k]))

# display genres for each artist
ag_dict = {p[0]: p[1] for p in sorted(ag_dict.items(), key=lambda kv: len(kv[0]), reverse=True)}

print(f'There are {len(ag_dict)} artists in the dataset. ' +
      f'Each artist only fits into {max(len(r) for r in list(ag_dict.values()))} genre.\n\n')
# Out:
# There are 591 artists in the dataset. Each artist only fits into 1 genre.
